# %%
import sys
# !{sys.executable} -m pip install dimcli

# %%
import dimcli
from dimcli.utils import *
import json, sys, time
import pandas as pd

# %%
dimcli.login(key=" xxxxxxxxxx", 
             endpoint="https://app.dimensions.ai")

dsl = dimcli.Dsl()
# Out:
# Dimcli - Dimensions API Client (v0.9)
# Connected to: https://app.dimensions.ai - DSL v1.31
# Method: manual login
# ====
# Heads up! The latest Dimcli version is  0.9.1
# You have installed:  0.9
# ====
# Please upgrade: `pip install dimcli -U`

# %%
#x = pd.concat(temp, ignore_index = True)
#x.institutes = x.institutes.explode() #changes the list into dictionary
#x.institutes = x.institutes.fillna({i: {} for i in x.index})  # replace NaN with '{}' if the column is strings, otherwise replace with {}
#x = x.join(pd.json_normalize(x.institutes)) # normalize the column of dictionaries and join it to df
#x.drop(columns=['institutes', 'geo.cities', 'geo.states', 'geo.countries'], inplace=True)
#x.to_csv("grid_matching.csv",index=False)

# %%
qs_institute_names = pd.read_csv('unique_qs_ranking_institutes.csv')

list_of_institutes = qs_institute_names.values.tolist()
list_of_institutes_test_1 = list_of_institutes[0:1000]
list_of_institutes_test_2 = list_of_institutes[1000:2000]
list_of_institutes_test_3 = list_of_institutes[2000:3000]
#list_of_institutes_test_4 = list_of_institutes[3000:4000]
#list_of_institutes_test_5 = list_of_institutes[4000:5000]
#list_of_institutes_test_6 = list_of_institutes[5000:6000]
#list_of_institutes_test_7 = list_of_institutes[6000:7000]
#list_of_institutes_test_8 = list_of_institutes[7000:8000]

# %%
institutes = []
for d in list_of_institutes_test_1:
    res = dsl.query(f"""extract_affiliations(affiliation="{d[0]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)

for d in list_of_institutes_test_2:
    res = dsl.query(f"""extract_affiliations(affiliation="{d[0]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)
    
for d in list_of_institutes_test_3:
    res = dsl.query(f"""extract_affiliations(affiliation="{d[0]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)
# Out:
# 1 QuerySyntaxError found
# 1 ParserError found
#   * [Line 1:72] ('MEPhI') mismatched input 'MEPhI' expecting ')'
# 1 QuerySyntaxError found
# 1 ParserError found
#   * [Line 1:81] ('MISIS') mismatched input 'MISIS' expecting ')'
# 2 QuerySyntaxErrors found
# 1 LexerError found
#   * [Line 1:66] ('Júlio de Mesquita Filho"")') token recognition error at: 'Jú'
# 1 ParserError found
#   * [Line 1:68] ('lio') mismatched input 'lio' expecting ')'
# 1 QuerySyntaxError found
# 1 ParserError found
#   * [Line 1:52] ('St') mismatched input 'St' expecting ')'
# 1 QuerySyntaxError found
# 1 ParserError found
#   * [Line 1:65] ('Kharkiv') mismatched input 'Kharkiv' expecting ')'
# 1 QuerySyntaxError found
# 1 ParserError found
#   * [Line 1:76] ('Kyiv') mismatched input 'Kyiv' expecting ')'
# 1 QuerySyntaxError found
# 1 ParserError found
#   * [Line 1:39] ('Gheorghe') mismatched input 'Gheorghe' expecting ')'
# 1 QuerySyntaxError found
# 1 ParserError found
# ...

# %%
institutes = []
for d in list_of_institutes_test_1:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)

for d in list_of_institutes_test_2:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)

for d in list_of_institutes_test_3:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)    
    
for d in list_of_institutes_test_4:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)
    
for d in list_of_institutes_test_5:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)
        
for d in list_of_institutes_test_6:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)
    
for d in list_of_institutes_test_7:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)
        
for d in list_of_institutes_test_8:
    res = dsl.query(f"""extract_affiliations(name="{d[0]}", city="{d[1]}", state="{d[2]}", country="{d[3]}")""")
    time.sleep(0.5)
    x = res.as_dataframe()
    institutes.append(x)

# %%
institutes_1_concat = pd.concat(institutes, ignore_index = True)
institutes_1_concat

institutes_1_concat.to_csv("qs_matched_to_grid.csv",index=False)

#institutes_1_concat = institutes_1_concat[institutes_1_concat.astype(str)['institutes'] != '[]']

#gets_all_grids_but_no_id_column = pd.concat([pd.DataFrame(json_normalize(x)) for x in institutes_1_concat['institutes']],ignore_index=True)

#test = pd.json_normalize(final_concat.institutes) # normalize the column of dictionaries and join it to df
#institutes_1_concat.drop(columns=['institutes', 'geo.cities', 'geo.states', 'geo.countries'], inplace=True)

#institutes_1_concat

#test

# %%
from IPython.display import display, HTML
display(HTML(institutes_1_concat_2.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>institute.id</th>
#       <th>institute.name</th>
#       <th>institute.city</th>
#       <th>institute.state</th>
#       <th>institute.country</th>
#       <th>metadata.requires_manual_review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>grid.412041.2</td>
#       <td>University of Bordeaux</td>
#       <td>Bordeaux</td>
#       <td>None</td>
#       <td>France</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>grid.412041.2</td>
#       <td>University of Bordeaux</td>
#       <td>Bordeaux</td>
#       <td>None</td>
#       <td>France</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>grid.412041.2</td>
#       <td>University of Bordeaux</td>
#       <td>Bordeaux</td>
#       <td>None</td>
#       <td>France</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...
